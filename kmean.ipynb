# %% [markdown]
# <a href="https://colab.research.google.com/github/Aashika100-jpg/AI-Lab/blob/main/kmean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Sample Data
X = np.array([
    [1, 2], [2, 3], [3, 3], [6, 5], [7, 8], [8, 9], [12, 10], [13, 12], [14, 13]
])

# Fit the KMeans model
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)

# Cluster Centers
centroids = kmeans.cluster_centers_

# Labels
labels = kmeans.labels_

# Plotting the data and cluster centers
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', s=200, c='red')
plt.title("K-Means Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

print("Cluster Centers:")
print(centroids)

print("Labels for each point:")
print(labels)
# Out:
# Cluster Centers:
# [[ 7.          7.33333333]
#  [ 2.          2.66666667]
#  [13.         11.66666667]]
# Labels for each point:
# [1 1 1 0 0 0 2 2 2]
